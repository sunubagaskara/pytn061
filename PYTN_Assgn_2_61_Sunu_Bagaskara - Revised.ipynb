# %%
# Get your import statement here
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd
# %matplotlib inline

# %%
# Load your dataset here
df = pd.read_csv('nyc-rolling-sales.csv')
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %% [markdown]
# Let's view the top 5 rows of the dataset using the head() function.

# %%
# Write your syntax here
df.head(5)
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# 2   39                                  C7   197 EAST 3RD   STREET  ...
# 3   21                                  C4     154 EAST 7TH STREET  ...
# 4   55                                  C2  301 EAST 10TH   STREET  ...
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                 5                 0            5              1633
# 1                28                 3           31              4616
# 2                16                 1           17              2212
# 3                10                 0           10              2272
# 4                 6                 0            6              2369
#
#    GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               6440       1900                         2
# 1              18690       1900                         2
# 2               7803       1900                         2
# 3               6794       1913                         2
# 4               4615       1900                         2
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                              C2     6625000  2017-07-19 00:00:00
# 1                              C7         -    2016-12-14 00:00:00
# 2                              C7         -    2016-12-09 00:00:00
# 3                              C4     3936272  2016-09-23 00:00:00
# 4                              C2     8000000  2016-11-17 00:00:00
#
# [5 rows x 22 columns]

# %%
df.tail(5)
# Out:
#        Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84543        8409        5      WOODROW
# 84544        8410        5      WOODROW
# 84545        8411        5      WOODROW
# 84546        8412        5      WOODROW
# 84547        8413        5      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                ADDRESS  \
# 84543   7349   34                                  B9          37 QUAIL LANE
# 84544   7349   78                                  B9       32 PHEASANT LANE
# 84545   7351   60                                  B2       49 PITNEY AVENUE
# 84546   7100   28                                  K6  2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9      155 CLAY PIT ROAD
#
#        ... RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 84543  ...                 2                 0            2              2400
# 84544  ...                 2                 0            2              2498
# 84545  ...                 2                 0            2              4000
# 84546  ...                 0                 7            7            208033
# 84547  ...                 0                 1            1             10796
#
#        GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 84543               2575       1998                         1
# 84544               2377       1998                         1
# 84545               1496       1925                         1
# 84546              64117       2001                         4
# 84547               2400       2006                         4
#
#        BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 84543                              B9      450000  2016-11-28 00:00:00
# 84544                              B9      550000  2017-04-21 00:00:00
# 84545                              B2      460000  2017-07-05 00:00:00
# 84546                              K6    11693337  2016-12-21 00:00:00
# 84547                              P9       69300  2016-10-27 00:00:00
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (84548, 22)

# %%
data = df.drop(['Unnamed: 0', 'EASE-MENT'], axis=1)
data
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                       2A    392    6                        C2
# 1                        2    399   26                        C7
# 2                        2    399   39                        C7
# 3                       2B    402   21                        C4
# 4                       2A    404   55                        C2
# ...                    ...    ...  ...                       ...
# 84543                    1   7349   34                        B9
# 84544                    1   7349   78                        B9
# 84545                    1   7351   60                        B2
# 84546                    4   7100   28                        K6
# 84547                    4   7105  679                        P9
#
#                       ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0                153 AVENUE B                      10009                  5
# 1       234 EAST 4TH   STREET                      10009                 28
# 2       197 EAST 3RD   STREET                      10009                 16
# 3         154 EAST 7TH STREET                      10009                 10
# 4      301 EAST 10TH   STREET                      10009                  6
# ...                       ...              ...       ...                ...
# 84543           37 QUAIL LANE                      10309                  2
# 84544        32 PHEASANT LANE                      10309                  2
# 84545        49 PITNEY AVENUE                      10309                  2
# 84546   2730 ARTHUR KILL ROAD                      10309                  0
# 84547       155 CLAY PIT ROAD                      10309                  0
#
#        COMMERCIAL UNITS  TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET  \
# 0                     0            5             1633              6440
# 1                     3           31             4616             18690
# 2                     1           17             2212              7803
# 3                     0           10             2272              6794
# 4                     0            6             2369              4615
# ...                 ...          ...              ...               ...
# 84543                 0            2             2400              2575
# 84544                 0            2             2498              2377
# 84545                 0            2             4000              1496
# 84546                 7            7           208033             64117
# 84547                 1            1            10796              2400
#
#        YEAR BUILT  TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  \
# 0            1900                          2                             C2
# 1            1900                          2                             C7
# 2            1900                          2                             C7
# 3            1913                          2                             C4
# 4            1900                          2                             C2
# ...           ...                        ...                            ...
# 84543        1998                          1                             B9
# 84544        1998                          1                             B9
# 84545        1925                          1                             B2
# 84546        2001                          4                             K6
# 84547        2006                          4                             P9
#
#       SALE PRICE            SALE DATE
# 0        6625000  2017-07-19 00:00:00
# 1            -    2016-12-14 00:00:00
# 2            -    2016-12-09 00:00:00
# 3        3936272  2016-09-23 00:00:00
# 4        8000000  2016-11-17 00:00:00
# ...          ...                  ...
# 84543     450000  2016-11-28 00:00:00
# 84544     550000  2017-04-21 00:00:00
# 84545     460000  2017-07-05 00:00:00
# 84546   11693337  2016-12-21 00:00:00
# 84547      69300  2016-10-27 00:00:00
#
# [84548 rows x 20 columns]

# %%
data['Borough1'] = df['BOROUGH'].replace({1:'Manhattan', 2:'Bronx', 3:'Brooklyn', 4:'Queens', 5:'Staten Island'})
data.head(5)
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 1                    2    399   26                        C7
# 2                    2    399   39                        C7
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  ...  COMMERCIAL UNITS  \
# 0            153 AVENUE B                      10009  ...                 0
# 1   234 EAST 4TH   STREET                      10009  ...                 3
# 2   197 EAST 3RD   STREET                      10009  ...                 1
# 3     154 EAST 7TH STREET                      10009  ...                 0
# 4  301 EAST 10TH   STREET                      10009  ...                 0
#
#    TOTAL UNITS  LAND SQUARE FEET GROSS SQUARE FEET YEAR BUILT  \
# 0            5              1633              6440       1900
# 1           31              4616             18690       1900
# 2           17              2212              7803       1900
# 3           10              2272              6794       1913
# 4            6              2369              4615       1900
#
#    TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 0                          2                              C2    6625000
# 1                          2                              C7        -
# 2                          2                              C7        -
# 3                          2                              C4    3936272
# 4                          2                              C2    8000000
#
#              SALE DATE   Borough1
# 0  2017-07-19 00:00:00  Manhattan
# 1  2016-12-14 00:00:00  Manhattan
# 2  2016-12-09 00:00:00  Manhattan
# 3  2016-09-23 00:00:00  Manhattan
# 4  2016-11-17 00:00:00  Manhattan
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84548 non-null  int64
#  1   NEIGHBORHOOD                    84548 non-null  object
#  2   BUILDING CLASS CATEGORY         84548 non-null  object
#  3   TAX CLASS AT PRESENT            84548 non-null  object
#  4   BLOCK                           84548 non-null  int64
#  5   LOT                             84548 non-null  int64
#  6   BUILDING CLASS AT PRESENT       84548 non-null  object
#  7   ADDRESS                         84548 non-null  object
#  8   APARTMENT NUMBER                84548 non-null  object
#  9   ZIP CODE                        84548 non-null  int64
#  10  RESIDENTIAL UNITS               84548 non-null  int64
#  11  COMMERCIAL UNITS                84548 non-null  int64
#  12  TOTAL UNITS                     84548 non-null  int64
#  13  LAND SQUARE FEET                84548 non-null  object
#  14  GROSS SQUARE FEET               84548 non-null  object
#  15  YEAR BUILT                      84548 non-null  int64
#  16  TAX CLASS AT TIME OF SALE       84548 non-null  int64
#  17  BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  18  SALE PRICE                      84548 non-null  object
#  19  SALE DATE                       84548 non-null  object
#  20  Borough1                        84548 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 13.5+ MB

# %%
data['SALE PRICE2'] = pd.to_numeric(data['SALE PRICE'], errors='coerce').convert_dtypes()

# %%
data
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                       2A    392    6                        C2
# 1                        2    399   26                        C7
# 2                        2    399   39                        C7
# 3                       2B    402   21                        C4
# 4                       2A    404   55                        C2
# ...                    ...    ...  ...                       ...
# 84543                    1   7349   34                        B9
# 84544                    1   7349   78                        B9
# 84545                    1   7351   60                        B2
# 84546                    4   7100   28                        K6
# 84547                    4   7105  679                        P9
#
#                       ADDRESS APARTMENT NUMBER  ZIP CODE  ...  TOTAL UNITS  \
# 0                153 AVENUE B                      10009  ...            5
# 1       234 EAST 4TH   STREET                      10009  ...           31
# 2       197 EAST 3RD   STREET                      10009  ...           17
# 3         154 EAST 7TH STREET                      10009  ...           10
# 4      301 EAST 10TH   STREET                      10009  ...            6
# ...                       ...              ...       ...  ...          ...
# 84543           37 QUAIL LANE                      10309  ...            2
# 84544        32 PHEASANT LANE                      10309  ...            2
# 84545        49 PITNEY AVENUE                      10309  ...            2
# 84546   2730 ARTHUR KILL ROAD                      10309  ...            7
# 84547       155 CLAY PIT ROAD                      10309  ...            1
#
#        LAND SQUARE FEET  GROSS SQUARE FEET YEAR BUILT  \
# 0                  1633               6440       1900
# 1                  4616              18690       1900
# 2                  2212               7803       1900
# 3                  2272               6794       1913
# 4                  2369               4615       1900
# ...                 ...                ...        ...
# 84543              2400               2575       1998
# 84544              2498               2377       1998
# 84545              4000               1496       1925
# 84546            208033              64117       2001
# 84547             10796               2400       2006
#
#       TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                             2                              C2     6625000
# 1                             2                              C7         -
# 2                             2                              C7         -
# 3                             2                              C4     3936272
# 4                             2                              C2     8000000
# ...                         ...                             ...         ...
# 84543                         1                              B9      450000
# 84544                         1                              B9      550000
# 84545                         1                              B2      460000
# 84546                         4                              K6    11693337
# 84547                         4                              P9       69300
#
#                  SALE DATE       Borough1 SALE PRICE2
# 0      2017-07-19 00:00:00      Manhattan   6625000.0
# 1      2016-12-14 00:00:00      Manhattan        <NA>
# 2      2016-12-09 00:00:00      Manhattan        <NA>
# 3      2016-09-23 00:00:00      Manhattan   3936272.0
# 4      2016-11-17 00:00:00      Manhattan   8000000.0
# ...                    ...            ...         ...
# 84543  2016-11-28 00:00:00  Staten Island    450000.0
# 84544  2017-04-21 00:00:00  Staten Island    550000.0
# 84545  2017-07-05 00:00:00  Staten Island    460000.0
# 84546  2016-12-21 00:00:00  Staten Island  11693337.0
# 84547  2016-10-27 00:00:00  Staten Island     69300.0
#
# [84548 rows x 22 columns]

# %%
# menghapus missing data
data = data.dropna()
data.head(10)
# Out:
#     BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9         1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 11        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 12        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 13        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 14        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 15        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
#
#    TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                    2A    392    6                        C2
# 3                    2B    402   21                        C4
# 4                    2A    404   55                        C2
# 6                    2B    406   32                        C4
# 9                     2    387  153                        D9
# 11                   2B    400   21                        D1
# 12                    2    373   40                        C6
# 13                    2    373   40                        C6
# 14                    2    373   40                        C6
# 15                    2    373   40                        C6
#
#                     ADDRESS APARTMENT NUMBER  ZIP CODE  ...  TOTAL UNITS  \
# 0              153 AVENUE B                      10009  ...            5
# 3       154 EAST 7TH STREET                      10009  ...           10
# 4    301 EAST 10TH   STREET                      10009  ...            6
# 6              210 AVENUE B                      10009  ...            8
# 9       629 EAST 5TH STREET                      10009  ...           24
# 11  530-532 EAST 5TH STREET                      10009  ...           10
# 12    327 EAST 3 STREET, 1C                      10009  ...            0
# 13    327 EAST 3 STREET, 1C                      10009  ...            0
# 14    327 EAST 3 STREET, 3A                      10009  ...            0
# 15  327 EAST 3RD STREET, 5A                      10009  ...            0
#
#     LAND SQUARE FEET  GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               1633               6440       1900                         2
# 3               2272               6794       1913                         2
# 4               2369               4615       1900                         2
# 6               1750               4226       1920                         2
# 9               4489              18523       1920                         2
# 11              3717              12350       2009                         2
# 12               -                  -         1920                         2
# 13               -                  -         1920                         2
# 14               -                  -         1920                         2
# 15               -                  -         1920                         2
#
#     BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE  \
# 0                               C2     6625000  2017-07-19 00:00:00
# 3                               C4     3936272  2016-09-23 00:00:00
# 4                               C2     8000000  2016-11-17 00:00:00
# 6                               C4     3192840  2016-09-23 00:00:00
# 9                               D9    16232000  2016-11-07 00:00:00
# 11                              D1    10350000  2016-10-17 00:00:00
# 12                              C6           1  2016-09-06 00:00:00
# 13                              C6      499000  2017-03-10 00:00:00
# 14                              C6          10  2017-04-28 00:00:00
# 15                              C6      529500  2017-06-09 00:00:00
#
#      Borough1 SALE PRICE2
# 0   Manhattan   6625000.0
# 3   Manhattan   3936272.0
# 4   Manhattan   8000000.0
# 6   Manhattan   3192840.0
# 9   Manhattan  16232000.0
# 11  Manhattan  10350000.0
# 12  Manhattan         1.0
# 13  Manhattan    499000.0
# 14  Manhattan        10.0
# 15  Manhattan    529500.0
#
# [10 rows x 22 columns]

# %%
data['SALE PRICE2'] = data['SALE PRICE2'].astype(np.int64)
data.head(5)
# Out:
# <ipython-input-70-9733c4429614>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SALE PRICE2'] = data['SALE PRICE2'].astype(np.int64)
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
# 6                   2B    406   32                        C4
# 9                    2    387  153                        D9
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  ...  TOTAL UNITS  \
# 0            153 AVENUE B                      10009  ...            5
# 3     154 EAST 7TH STREET                      10009  ...           10
# 4  301 EAST 10TH   STREET                      10009  ...            6
# 6            210 AVENUE B                      10009  ...            8
# 9     629 EAST 5TH STREET                      10009  ...           24
#
#    LAND SQUARE FEET  GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0              1633               6440       1900                         2
# 3              2272               6794       1913                         2
# 4              2369               4615       1900                         2
# 6              1750               4226       1920                         2
# 9              4489              18523       1920                         2
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE   Borough1  \
# 0                              C2     6625000  2017-07-19 00:00:00  Manhattan
# 3                              C4     3936272  2016-09-23 00:00:00  Manhattan
# 4                              C2     8000000  2016-11-17 00:00:00  Manhattan
# 6                              C4     3192840  2016-09-23 00:00:00  Manhattan
# 9                              D9    16232000  2016-11-07 00:00:00  Manhattan
#
#   SALE PRICE2
# 0     6625000
# 3     3936272
# 4     8000000
# 6     3192840
# 9    16232000
#
# [5 rows x 22 columns]

# %%
# menghapus missing data
data = data.dropna()
data.head(10)
# Out:
#     BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6         1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9         1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 11        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 12        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 13        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 14        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 15        1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
#
#    TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                    2A    392    6                        C2
# 3                    2B    402   21                        C4
# 4                    2A    404   55                        C2
# 6                    2B    406   32                        C4
# 9                     2    387  153                        D9
# 11                   2B    400   21                        D1
# 12                    2    373   40                        C6
# 13                    2    373   40                        C6
# 14                    2    373   40                        C6
# 15                    2    373   40                        C6
#
#                     ADDRESS APARTMENT NUMBER  ZIP CODE  ...  TOTAL UNITS  \
# 0              153 AVENUE B                      10009  ...            5
# 3       154 EAST 7TH STREET                      10009  ...           10
# 4    301 EAST 10TH   STREET                      10009  ...            6
# 6              210 AVENUE B                      10009  ...            8
# 9       629 EAST 5TH STREET                      10009  ...           24
# 11  530-532 EAST 5TH STREET                      10009  ...           10
# 12    327 EAST 3 STREET, 1C                      10009  ...            0
# 13    327 EAST 3 STREET, 1C                      10009  ...            0
# 14    327 EAST 3 STREET, 3A                      10009  ...            0
# 15  327 EAST 3RD STREET, 5A                      10009  ...            0
#
#     LAND SQUARE FEET  GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               1633               6440       1900                         2
# 3               2272               6794       1913                         2
# 4               2369               4615       1900                         2
# 6               1750               4226       1920                         2
# 9               4489              18523       1920                         2
# 11              3717              12350       2009                         2
# 12               -                  -         1920                         2
# 13               -                  -         1920                         2
# 14               -                  -         1920                         2
# 15               -                  -         1920                         2
#
#     BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE  \
# 0                               C2     6625000  2017-07-19 00:00:00
# 3                               C4     3936272  2016-09-23 00:00:00
# 4                               C2     8000000  2016-11-17 00:00:00
# 6                               C4     3192840  2016-09-23 00:00:00
# 9                               D9    16232000  2016-11-07 00:00:00
# 11                              D1    10350000  2016-10-17 00:00:00
# 12                              C6           1  2016-09-06 00:00:00
# 13                              C6      499000  2017-03-10 00:00:00
# 14                              C6          10  2017-04-28 00:00:00
# 15                              C6      529500  2017-06-09 00:00:00
#
#      Borough1 SALE PRICE2
# 0   Manhattan     6625000
# 3   Manhattan     3936272
# 4   Manhattan     8000000
# 6   Manhattan     3192840
# 9   Manhattan    16232000
# 11  Manhattan    10350000
# 12  Manhattan           1
# 13  Manhattan      499000
# 14  Manhattan          10
# 15  Manhattan      529500
#
# [10 rows x 22 columns]

# %%
# menghapus harga rumah <$100.000,-
data = data[data['SALE PRICE2'] > 100000]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57026 entries, 0 to 84546
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         57026 non-null  int64
#  1   NEIGHBORHOOD                    57026 non-null  object
#  2   BUILDING CLASS CATEGORY         57026 non-null  object
#  3   TAX CLASS AT PRESENT            57026 non-null  object
#  4   BLOCK                           57026 non-null  int64
#  5   LOT                             57026 non-null  int64
#  6   BUILDING CLASS AT PRESENT       57026 non-null  object
#  7   ADDRESS                         57026 non-null  object
#  8   APARTMENT NUMBER                57026 non-null  object
#  9   ZIP CODE                        57026 non-null  int64
#  10  RESIDENTIAL UNITS               57026 non-null  int64
#  11  COMMERCIAL UNITS                57026 non-null  int64
#  12  TOTAL UNITS                     57026 non-null  int64
#  13  LAND SQUARE FEET                57026 non-null  object
#  14  GROSS SQUARE FEET               57026 non-null  object
#  15  YEAR BUILT                      57026 non-null  int64
#  16  TAX CLASS AT TIME OF SALE       57026 non-null  int64
#  17  BUILDING CLASS AT TIME OF SALE  57026 non-null  object
#  18  SALE PRICE                      57026 non-null  object
#  19  SALE DATE                       57026 non-null  object
#  20  Borough1                        57026 non-null  object
#  21  SALE PRICE2                     57026 non-null  int64
# dtypes: int64(10), object(12)
# memory usage: 10.0+ MB

# %%
print('Column name')
for col in data.columns:
    if data[col].dtype=='object':
        print(col,data[col].nunique())
# Out:
# Column name
# NEIGHBORHOOD 253
# BUILDING CLASS CATEGORY 45
# TAX CLASS AT PRESENT 10
# BUILDING CLASS AT PRESENT 150
# ADDRESS 47543
# APARTMENT NUMBER 2887
# LAND SQUARE FEET 4706
# GROSS SQUARE FEET 4423
# BUILDING CLASS AT TIME OF SALE 150
# SALE PRICE 9543
# SALE DATE 331
# Borough1 5

# %%
numer = ['LAND SQUARE FEET','GROSS SQUARE FEET', 'SALE PRICE', 'BOROUGH']
for col in numer:
    data[col] = pd.to_numeric(data[col], errors='coerce')
    
categ = ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'BUILDING CLASS AT TIME OF SALE', 'TAX CLASS AT TIME OF SALE']
for col in categ:
    data[col] = data[col].astype('category')
    
data['SALE DATE'] = pd.to_datetime(data['SALE DATE'], errors='coerce')

# %%
missing = data.isnull().sum()/len(data)*100

print(pd.DataFrame([missing[missing>0], pd.Series(df.isnull().sum()[df.isnull().sum()>1000])], index=['percent missing', 'how many missing']))
# Out:
#                   LAND SQUARE FEET  GROSS SQUARE FEET
# percent missing          30.274194          31.061483
# how many missing               NaN                NaN

# %%
numer
# Out:
# ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'SALE PRICE', 'BOROUGH']

# %%
print(data[(data['LAND SQUARE FEET'].isnull()) & (data['GROSS SQUARE FEET'].notnull())].shape)
print(data[(data['LAND SQUARE FEET'].notnull()) & (data['GROSS SQUARE FEET'].isnull())].shape)
# Out:
# (4, 22)
# (447, 22)

# %%
data['LAND SQUARE FEET'] = data['LAND SQUARE FEET'].mask((data['LAND SQUARE FEET'].isnull()) & (data['GROSS SQUARE FEET'].notnull()), data['GROSS SQUARE FEET'])
data['GROSS SQUARE FEET'] = data['GROSS SQUARE FEET'].mask((data['LAND SQUARE FEET'].notnull()) & (data['GROSS SQUARE FEET'].isnull()), data['LAND SQUARE FEET'])

# %%
print(sum(data.duplicated()))

data[data.duplicated(keep=False)].sort_values(['NEIGHBORHOOD', 'ADDRESS']).head(10)
# Out:
# 81
#        BOROUGH        NEIGHBORHOOD  \
# 76383        5       ARDEN HEIGHTS
# 76384        5       ARDEN HEIGHTS
# 50265        4             ASTORIA
# 50266        4             ASTORIA
# 26202        3           BAY RIDGE
# 26203        3           BAY RIDGE
# 27499        3  BEDFORD STUYVESANT
# 27500        3  BEDFORD STUYVESANT
# 52168        4        BELLE HARBOR
# 52169        4        BELLE HARBOR
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 76383  01 ONE FAMILY DWELLINGS                                        1
# 76384  01 ONE FAMILY DWELLINGS                                        1
# 50265  07 RENTALS - WALKUP APARTMENTS                                 2
# 50266  07 RENTALS - WALKUP APARTMENTS                                 2
# 26202  10 COOPS - ELEVATOR APARTMENTS                                 2
# 26203  10 COOPS - ELEVATOR APARTMENTS                                 2
# 27499  12 CONDOS - WALKUP APARTMENTS                                  2
# 27500  12 CONDOS - WALKUP APARTMENTS                                  2
# 52168  01 ONE FAMILY DWELLINGS                                        1
# 52169  01 ONE FAMILY DWELLINGS                                        1
#
#        BLOCK   LOT BUILDING CLASS AT PRESENT                  ADDRESS  \
# 76383   5741    93                        A5           266 ILYSSA WAY
# 76384   5741    93                        A5           266 ILYSSA WAY
# 50265    839    21                        C1  27-01 ASTORIA BOULEVARD
# 50266    839    21                        C1  27-01 ASTORIA BOULEVARD
# 26202   5906    18                        D4                180 72 ST
# 26203   5906    18                        D4                180 72 ST
# 27499   1953  1110                        R2        142 CLIFTON PLACE
# 27500   1953  1110                        R2        142 CLIFTON PLACE
# 52168  16196    23                        A1   533 BEACH 128TH STREET
# 52169  16196    23                        A1   533 BEACH 128TH STREET
#
#       APARTMENT NUMBER  ZIP CODE  ...  TOTAL UNITS  LAND SQUARE FEET  \
# 76383                      10312  ...            1             500.0
# 76384                      10312  ...            1             500.0
# 50265                      11102  ...           20            4710.0
# 50266                      11102  ...           20            4710.0
# 26202                      11209  ...            0               0.0
# 26203                      11209  ...            0               0.0
# 27499               1B     11238  ...            1               0.0
# 27500               1B     11238  ...            1               0.0
# 52168                      11694  ...            1            4000.0
# 52169                      11694  ...            1            4000.0
#
#        GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 76383             1354.0        1996                          1
# 76384             1354.0        1996                          1
# 50265            11324.0        1973                          2
# 50266            11324.0        1973                          2
# 26202                0.0        1932                          2
# 26203                0.0        1932                          2
# 27499                0.0        2010                          2
# 27500                0.0        2010                          2
# 52168             2186.0        1945                          1
# 52169             2186.0        1945                          1
#
#        BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE       Borough1  \
# 76383                              A5     320000 2017-06-06  Staten Island
# 76384                              A5     320000 2017-06-06  Staten Island
# 50265                              C1     832500 2017-04-07         Queens
# 50266                              C1     832500 2017-04-07         Queens
# 26202                              D4     355050 2017-04-28       Brooklyn
# 26203                              D4     355050 2017-04-28       Brooklyn
# 27499                              R2     995000 2016-12-29       Brooklyn
# 27500                              R2     995000 2016-12-29       Brooklyn
# 52168                              A1    1150000 2017-08-07         Queens
# 52169                              A1    1150000 2017-08-07         Queens
#
#       SALE PRICE2
# 76383      320000
# 76384      320000
# 50265      832500
# 50266      832500
# 26202      355050
# 26203      355050
# 27499      995000
# 27500      995000
# 52168     1150000
# 52169     1150000
#
# [10 rows x 22 columns]

# %%
data[data['COMMERCIAL UNITS']==0].describe()
# Out:
#             BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  54406.000000  54406.000000  54406.000000  54406.000000
# mean       2.935945   4145.700419    407.201026  10708.951788
# std        1.341509   3575.146291    680.237118   1225.658391
# min        1.000000      1.000000      1.000000      0.000000
# 25%        1.000000   1270.000000     22.000000  10128.000000
# 50%        3.000000   3150.000000     52.000000  11206.000000
# 75%        4.000000   6124.000000   1005.000000  11357.000000
# max        5.000000  16319.000000   9106.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  \
# count       54406.000000           54406.0  54406.000000      3.381500e+04
# mean            1.461015               0.0      1.469139      3.019633e+03
# std             8.652159               0.0      8.651253      3.503505e+04
# min             0.000000               0.0      0.000000      0.000000e+00
# 25%             0.000000               0.0      0.000000      1.300000e+03
# 50%             1.000000               0.0      1.000000      2.200000e+03
# 75%             1.000000               0.0      1.000000      3.192500e+03
# max           771.000000               0.0    771.000000      4.252327e+06
#
#        GROSS SQUARE FEET    YEAR BUILT    SALE PRICE   SALE PRICE2
# count       3.381500e+04  54406.000000  5.440600e+04  5.440600e+04
# mean        2.494232e+03   1811.069386  1.200352e+06  1.200352e+06
# std         3.218150e+04    505.610959  3.623154e+06  3.623154e+06
# min         0.000000e+00      0.000000  1.003350e+05  1.003350e+05
# 25%         8.000000e+02   1920.000000  4.000000e+05  4.000000e+05
# 50%         1.496000e+03   1945.000000  6.382210e+05  6.382210e+05
# 75%         2.208000e+03   1969.000000  1.046685e+06  1.046685e+06
# max         4.252327e+06   2017.000000  3.450000e+08  3.450000e+08

# %%
data[data['RESIDENTIAL UNITS']==0].describe()
# Out:
#             BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  17543.000000  17543.000000  17543.000000  17543.000000
# mean       2.412643   3141.597845    205.996523  10365.771875
# std        1.342326   2891.200660    495.313011   1911.207639
# min        1.000000      1.000000      1.000000      0.000000
# 25%        1.000000   1158.000000      9.000000  10023.000000
# 50%        3.000000   1727.000000     32.000000  10463.000000
# 75%        4.000000   5206.000000     69.000000  11354.000000
# max        5.000000  16315.000000   9056.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  \
# count            17543.0      17543.000000  17543.000000      5.400000e+03
# mean                 0.0          0.410420      0.435615      8.044833e+03
# std                  0.0         18.112213     18.112320      1.001105e+05
# min                  0.0          0.000000      0.000000      0.000000e+00
# 25%                  0.0          0.000000      0.000000      0.000000e+00
# 50%                  0.0          0.000000      0.000000      0.000000e+00
# 75%                  0.0          0.000000      0.000000      2.500000e+03
# max                  0.0       2261.000000   2261.000000      4.252327e+06
#
#        GROSS SQUARE FEET    YEAR BUILT    SALE PRICE   SALE PRICE2
# count       5.400000e+03  17543.000000  1.754300e+04  1.754300e+04
# mean        8.437428e+03   1779.990595  1.945627e+06  1.945627e+06
# std         8.919406e+04    544.352033  2.146980e+07  2.146980e+07
# min         0.000000e+00      0.000000  1.003350e+05  1.003350e+05
# 25%         0.000000e+00   1926.000000  2.700000e+05  2.700000e+05
# 50%         0.000000e+00   1950.000000  5.000000e+05  5.000000e+05
# 75%         1.522500e+03   1961.000000  9.922630e+05  9.922630e+05
# max         4.252327e+06   2016.000000  2.210000e+09  2.210000e+09

# %% [markdown]
# Findings:
# - There are zipcodes with 0 value
# - Year column has a year with 0
# - Land square feet and gross square feet has minimum of 0

# %%
data.value_counts('Borough1')
# Out:
# Borough1
# Queens           17668
# Brooklyn         14870
# Manhattan        14056
# Staten Island     5731
# Bronx             4701
# dtype: int64

# %% [markdown]
# From here, we can calculate the mean for each Borough. Use .mean() function to calculate mean.
#
# Function below are graded function. (1 Points)

# %%
# Write your function below
data.groupby('Borough1').mean()

# Graded-Funtion Begin (~1 Lines)

# Graded-Funtion End
# Out:
#                BOROUGH        BLOCK         LOT      ZIP CODE  \
# Borough1
# Bronx              2.0  4264.940651  295.876409  10410.930440
# Brooklyn           3.0  4207.785205  371.610424  11074.059852
# Manhattan          1.0  1105.690168  719.091064   9909.089286
# Queens             4.0  6705.273432  235.346389  11323.190627
# Staten Island      5.0  3326.285988  198.670913  10157.016577
#
#                RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# Borough1
# Bronx                   3.151032          0.142310     3.294193
# Brooklyn                1.744654          0.106927     1.858036
# Manhattan               1.682555          0.150968     1.846756
# Queens                  1.460154          0.257528     1.724417
# Staten Island           1.247775          0.083406     1.330483
#
#                LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT    SALE PRICE  \
# Borough1
# Bronx               3408.252287        3914.606679  1803.801744  8.810218e+05
# Brooklyn            1973.391459        2073.666106  1776.555952  1.348161e+06
# Manhattan           5757.291667       31084.446581  1739.401039  3.428086e+06
# Queens              4063.467240        3081.611790  1878.498925  7.709806e+05
# Staten Island       8165.811506        4757.123110  1928.325423  5.688194e+05
#
#                 SALE PRICE2
# Borough1
# Bronx          8.810218e+05
# Brooklyn       1.348161e+06
# Manhattan      3.428086e+06
# Queens         7.709806e+05
# Staten Island  5.688194e+05

# %% [markdown]
# From here, we can calculate the median for each Borough. Use .median() function to calculate median.
#
# Function below are graded function. (1 Points)

# %%
# Write your function below
data.groupby('Borough1').median()
# Graded-Funtion Begin (~1 Lines)

# Graded-Funtion End
# Out:
#                BOROUGH   BLOCK     LOT  ZIP CODE  RESIDENTIAL UNITS  \
# Borough1
# Bronx              2.0  4287.0    47.0   10465.0                1.0
# Brooklyn           3.0  4246.5    52.0   11219.0                1.0
# Manhattan          1.0  1171.0  1002.0   10022.0                0.0
# Queens             4.0  6020.5    39.0   11375.0                1.0
# Staten Island      5.0  3121.0    57.0   10308.0                1.0
#
#                COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# Borough1
# Bronx                       0.0          1.0            2300.0
# Brooklyn                    0.0          1.0            1620.0
# Manhattan                   0.0          0.0            2469.0
# Queens                      0.0          1.0            2794.0
# Staten Island               0.0          1.0            3431.0
#
#                GROSS SQUARE FEET  YEAR BUILT  SALE PRICE  SALE PRICE2
# Borough1
# Bronx                     1734.0      1935.0    427665.0     427665.0
# Brooklyn                  1238.0      1930.0    795000.0     795000.0
# Manhattan                 7000.0      1939.0   1200000.0    1200000.0
# Queens                    1632.0      1945.0    510200.0     510200.0
# Staten Island             1580.0      1975.0    475000.0     475000.0

# %% [markdown]
# From here, we can calculate the mode for each Borough.
#
# Function below are graded function. (1 Points)

# %%
# Write your function below
data.groupby('Borough1').agg(pd.Series.mode)
# Graded-Funtion Begin (~1 Lines)

# Graded-Funtion End
# Out:
#                BOROUGH             NEIGHBORHOOD  \
# Borough1
# Bronx                2                RIVERDALE
# Brooklyn             3       BEDFORD STUYVESANT
# Manhattan            1  UPPER EAST SIDE (59-79)
# Queens               4           FLUSHING-NORTH
# Staten Island        5              GREAT KILLS
#
#                                    BUILDING CLASS CATEGORY  \
# Borough1
# Bronx          02 TWO FAMILY DWELLINGS
# Brooklyn       02 TWO FAMILY DWELLINGS
# Manhattan      13 CONDOS - ELEVATOR APARTMENTS
# Queens         01 ONE FAMILY DWELLINGS
# Staten Island  01 ONE FAMILY DWELLINGS
#
#               TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# Borough1
# Bronx                            1   3944    1                        D4
# Brooklyn                         1   2135    1                        R4
# Manhattan                        2     16    1                        R4
# Queens                           1   5066    1                        D4
# Staten Island                    1   2450    1                        A5
#
#                            ADDRESS APARTMENT NUMBER  ZIP CODE  ...  \
# Borough1                                                       ...
# Bronx          2287 JOHNSON AVENUE                      10463  ...
# Brooklyn           429 KENT AVENUE                      11201  ...
# Manhattan           50 WEST STREET                      10011  ...
# Queens          131-05 40TH   ROAD                      11354  ...
# Staten Island   145 LINCOLN AVENUE                      10314  ...
#
#                COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# Borough1
# Bronx                         0            1               0.0
# Brooklyn                      0            1               0.0
# Manhattan                     0            0            2523.0
# Queens                        0            1            4000.0
# Staten Island                 0            1            4000.0
#
#                                   GROSS SQUARE FEET YEAR BUILT  \
# Borough1
# Bronx                                           0.0       1920
# Brooklyn                                        0.0          0
# Manhattan      [2500.0, 7000.0, 112850.0, 267008.0]          0
# Queens                                       1224.0       1920
# Staten Island                                1200.0       1970
#
#                TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# Borough1
# Bronx                                  1                              D4
# Brooklyn                               1                              R4
# Manhattan                              2                              R4
# Queens                                 1                              D4
# Staten Island                          1                              A5
#
#               SALE PRICE                                          SALE DATE  \
# Borough1
# Bronx             500000                                2017-04-06 00:00:00
# Brooklyn          650000                                2017-06-29 00:00:00
# Manhattan        1100000                                2017-06-29 00:00:00
# Queens            450000                                2016-12-22 00:00:00
# Staten Island     450000  [2016-10-27 00:00:00, 2016-11-17 00:00:00, 201...
#
#               SALE PRICE2
# Borough1
# Bronx              500000
# Brooklyn           650000
# Manhattan         1100000
# Queens             450000
# Staten Island      450000
#
# [5 rows x 21 columns]

# %% [markdown]
# From here, we can calculate the Range for each Borough.
#
# Function below are graded function. (1 Points)

# %%
# Write your function below
data.groupby("Borough1")["SALE PRICE2"].max() - data.groupby("Borough1")["SALE PRICE2"].min()
# Graded-Funtion Begin (~1 Lines)

# Graded-Funtion End
# Out:
# Borough1
# Bronx             109898500
# Brooklyn          344899000
# Manhattan        2209899665
# Queens            257399000
# Staten Island     121899300
# Name: SALE PRICE2, dtype: int64

# %% [markdown]
# From here, we can calculate the Variance for each Borough.
#
# Function below are graded function. (1 Points)

# %%
# Write your function below
data.groupby('BOROUGH').var()
# Graded-Funtion Begin (~1 Lines)

# Graded-Funtion End
# Out:
#                 BLOCK            LOT      ZIP CODE  RESIDENTIAL UNITS  \
# BOROUGH
# 1        2.946769e+05  766908.527459  1.203575e+06         314.718432
# 2        1.165565e+06  560038.003658  5.563639e+05         478.641014
# 3        7.480779e+06  297522.367219  1.621358e+06          31.610024
# 4        1.819829e+07  252813.424696  6.020038e+05         239.712512
# 5        5.448781e+06  182953.811054  1.534881e+06           4.577340
#
#          COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# BOROUGH
# 1               13.720074   332.058905      2.063514e+08       1.133192e+10
# 2                0.687190   495.025985      2.844557e+08       5.365024e+08
# 3                0.346223    32.216377      2.923794e+08       9.645209e+07
# 4              312.993731   557.213516      1.690191e+09       1.440589e+09
# 5                5.628644    10.068074      9.606694e+09       6.459261e+09
#
#             YEAR BUILT    SALE PRICE   SALE PRICE2
# BOROUGH
# 1        371602.450825  5.962210e+14  5.962210e+14
# 2        253702.338559  1.136058e+13  1.136058e+13
# 3        301475.054472  2.435976e+13  2.435976e+13
# 4        133805.626025  1.089249e+13  1.089249e+13
# 5         81854.745216  3.779595e+12  3.779595e+12

# %% [markdown]
# From here, we can calculate the SD for each Borough.
#
# Function below are graded function. (1 Points)

# %%
# Write your function below
data.groupby('Borough1').std(ddof=1)
# Graded-Funtion Begin (~1 Lines)

# Graded-Funtion End
# Out:
#                BOROUGH        BLOCK         LOT     ZIP CODE  \
# Borough1
# Bronx              0.0  1079.613157  748.356869   745.898023
# Brooklyn           0.0  2735.101288  545.456109  1273.325721
# Manhattan          0.0   542.841516  875.733137  1097.075557
# Queens             0.0  4265.944835  502.805554   775.889027
# Staten Island      0.0  2334.262444  427.731003  1238.902970
#
#                RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# Borough1
# Bronx                  21.877866          0.828969    22.249179
# Brooklyn                5.622279          0.588407     5.675947
# Manhattan              17.740305          3.704062    18.222484
# Queens                 15.482652         17.691629    23.605370
# Staten Island           2.139472          2.372476     3.173023
#
#                LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT    SALE PRICE  \
# Borough1
# Bronx              16865.815131       23162.520921  503.688732  3.370546e+06
# Brooklyn           17099.106266        9821.002663  549.067441  4.935560e+06
# Manhattan          14364.937517      106451.489560  609.592036  2.441764e+07
# Queens             41111.930145       37955.087228  365.794513  3.300377e+06
# Staten Island      98013.743760       80369.524994  286.102683  1.944118e+06
#
#                 SALE PRICE2
# Borough1
# Bronx          3.370546e+06
# Brooklyn       4.935560e+06
# Manhattan      2.441764e+07
# Queens         3.300377e+06
# Staten Island  1.944118e+06

# %% [markdown]
# Now we can analyze Probability Distibution below.
#
# Function below are graded function. (1 Points)

# %%
from scipy.stats import norm

# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image

import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})

from scipy.stats import uniform

# %%
# Write your function below
sns.displot(
    data=data,
    x='SALE PRICE2',
    hue='Borough1',
    kind='hist',
    aspect=1.4,
    log_scale=10,
    bins=20,
    kde=True
)
# Graded-Funtion Begin





# Graded-Funtion End

# %% [markdown]
# Now we can analyze Confidence Intervals below.
#
# Function below are graded function. (1 Points)

# %%
# menghitung CI untuk Sale Price di Borough Manhattan
sale = data[["Borough1","SALE PRICE2"]]
print(sale.shape)
sale.head()
# Out:
# (57026, 2)
#     Borough1  SALE PRICE2
# 0  Manhattan      6625000
# 3  Manhattan      3936272
# 4  Manhattan      8000000
# 6  Manhattan      3192840
# 9  Manhattan     16232000

# %%
sale.groupby('Borough1').agg({"SALE PRICE2": [np.mean, np.std, np.size]})
# Out:
#                 SALE PRICE2
#                        mean           std   size
# Borough1
# Bronx          8.810218e+05  3.370546e+06   4701
# Brooklyn       1.348161e+06  4.935560e+06  14870
# Manhattan      3.428086e+06  2.441764e+07  14056
# Queens         7.709806e+05  3.300377e+06  17668
# Staten Island  5.688194e+05  1.944118e+06   5731

# %%
mean_man = 3428085.84 # mean harga jual di Manhattan
sd_man = 2441764 # standard deviation harga jual di Manhattan
n_man = 14056 # total jumlah penjualan rumah di Manhattan
z_man = 1.96 # skor z

# %%
se_man = sd_man / np.sqrt(n_man)
se_man
# Out:
# 20595.522400496317

# %%
lcb = mean_man - z_man* se_man
ucb = mean_man + z_man* se_man
lcb, ucb
# Out:
# (3387718.616095027, 3468453.0639049727)

# %% [markdown]
# 95% keyakinan bahwa harga jual properti di Manhattan ada di antara $3,387,719 - $3,468,453

# %% [markdown]
# Make your Hypothesis Testing below
#
# Function below are graded function. (1 Points)

# %%
import statsmodels.api as sm

# %%
bronx = data[data['Borough1'] == 'Bronx']
queens = data[data['Borough1'] == 'Queens']

n_b = len(bronx)
mean_b = bronx['SALE PRICE2'].mean()
std_b = bronx['SALE PRICE2'].std()

n_q = len(queens)
mean_q = queens['SALE PRICE2'].mean()
std_q = queens['SALE PRICE2'].std()

print(n_b, mean_b, std_b)
print(n_q, mean_q, std_q)
# Out:
# 4701 881021.7747287811 3370546.279830777
# 17668 770980.5930495812 3300377.383809735

# %%
# Write your function below
print(("zstat", "p-value"))
sm.stats.ztest(bronx["SALE PRICE2"], queens["SALE PRICE2"], alternative='two-sided')

# Graded-Funtion Begin





# Graded-Funtion End
# Out:
# ('zstat', 'p-value')
# (2.0225772312577326, 0.04311675362015392)

# %% [markdown]
# - p value < alpha
# - 0.043 < 0.05
# - hipotesis nol dapat ditolak
#
# kesimpulan: harga jual properti antara borough Bronx dan Queens berbeda secara signifikan
